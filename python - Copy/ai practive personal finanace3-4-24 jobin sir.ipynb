# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd

# Replace 'file_path.csv' with the path to your CSV file
df = pd.read_csv('Personal Finance.csv')

# Display the DataFrame
print(df)

# %%
# Print the first few rows of the DataFrame
print(df.head())

# %%
# Print the shape of the DataFrame
print(df.shape)

# %%
df['CUSTOMER ID']

# %%
df['ANNUAL INCOME(k$)']

# %%
# Rename the column
df = df.rename(columns={'ANNUAL INCOME(k$)': 'ANNUAL INCOME'})

# %%
df

# %%
y=df['SPENDING SCORE(1-100)']
x=df.drop(columns=['SPENDING SCORE(1-100)'])
y
x

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

print("x_train shape:",x_train.shape)
print("x_test shape:",x_test.shape)
print("y_train shape:",y_train.shape)
print("y_test shape:",y_test.shape)

# %%
x_train

# %%
x_test

# %%
df

# %%
from sklearn.preprocessing import LabelEncoder

# Create a LabelEncoder instance
label_encoder = LabelEncoder()

# Fit and transform the 'GENDER' column in the training data
x_train["GENDER"] = label_encoder.fit_transform(x_train["GENDER"])

# Transform the 'GENDER' column in the test data (assuming it's already fit on the training data)
x_test["GENDER"] = label_encoder.transform(x_test["GENDER"])

# Print the modified dataframes
print(x_train)
print(x_test)

# %%
# prompt: support vector machine regressor fitting data

from sklearn.svm import SVR

# Instantiate the SVR model
svm_model = SVR(kernel='poly')

# Fit the model on the training data
svm_model.fit(x_train, y_train)

# Predict on the test data
svm_predicted = svm_model.predict(x_test)

# Print the predicted values
print(svm_predicted)

# %%
from sklearn.metrics import mean_absolute_error
svm_mae = mean_absolute_error(y_test, svm_predicted)
print("Mean absolute error:", svm_mae)

# %%
81-57.2867565

# %%
# Assuming you have already trained your SVM model and made predictions
# svm_prediction = svm_model.predict(X_test)

from sklearn.metrics import mean_squared_error
from math import sqrt

# Calculate the mean squared error
mean_sqrd_error = mean_squared_error(y_test, svm_predicted)

# Calculate the root mean squared error
RMSE = sqrt(mean_sqrd_error)

# %%
# Assuming you have already trained your SVM model and made predictions
# svm_prediction = svm_model.predict(X_test)

from sklearn.metrics import mean_squared_error
from math import sqrt

# Calculate the mean squared error
mean_sqrd_error = mean_squared_error(y_test, svm_predicted)

# Calculate the root mean squared error
RMSE = sqrt(mean_sqrd_error)

# %% [markdown]
# ![Screenshot (27)_LI.jpg](data:image/jpeg;base64,...)

# %%
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error
from math import sqrt

# Assuming you have your training data X_train, y_train and test data X_test, y_test

# Train your SVM model
svm_model = SVR(kernel='linear')
svm_model.fit(x_train, y_train)

# Make predictions on the test data
svm_prediction = svm_model.predict(x_test)

# Calculate the mean squared error
mean_sqrd_error = mean_squared_error(y_test, svm_prediction)

# Calculate the root mean squared error
RMSE = sqrt(mean_sqrd_error)

# Print or use the MSE and RMSE
print("Mean Squared Error:", mean_sqrd_error)
print("Root Mean Squared Error:", RMSE)

# %% [markdown]
# ![Screenshot (30).png](data:image/png;base64,...)

# %%
(23.31481481481481/81)*100

# %%
Details = {'CUSTOMER ID': [50], 'GENDER':[1],'AGE':[75],'ANNUAL INCOME':[500]}
PerFinNew=pd.DataFrame.from_dict(Details)
PerFinNewsvm_predicted = svm_model.predict(PerFinNew)
print(svm_prediction)

# %%
# Rename the column "ANNUAL INCOME" to "ANNUL INCOME"
PerFinNew.rename(columns={'ANNUAL INCOME': 'ANNUAL INCOME'}, inplace=True)

# Make predictions on the test data
svm_prediction1 = svm_model.predict(PerFinNew)

print(svm_prediction1)

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error
from math import sqrt

dt_model = DecisionTreeRegressor()
dt_model.fit(x_train, y_train)
dt_prediction = dt_model.predict(x_test)

# Calculate mean absolute error
dt_mae = mean_absolute_error(y_test, dt_prediction)
print("Mean Absolute Error:", dt_mae)

# Calculate mean squared error
mean_sqrd_error_dt = mean_squared_error(y_test, dt_prediction)
print("Mean Squared Error:", mean_sqrd_error_dt)

# Calculate root mean squared error
RMSE_dt = sqrt(mean_sqrd_error_dt)
print("Root Mean Squared Error:", RMSE_dt)

# %% [markdown]
# ![Screenshot (29).png](data:image/png;base64,...)

# %%
from sklearn.preprocessing import StandardScaler
std_scaler = StandardScaler()

scaled_x_train = pd.DataFrame(std_scaler.fit_transform(x_train),columns =x_train.columns,index =x_train.index)
scaled_x_train

# %%
from sklearn.preprocessing import StandardScaler
scaled_x_test = pd.DataFrame(std_scaler.fit_transform(x_test),columns =x_test.columns,index =x_test.index)
scaled_x_test
